# %%
import cv2
from PIL import Image
import pytesseract
import numpy as np
import matplotlib.pyplot as plt
import os



image = Image.open('images/image.png')

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=829x916>
